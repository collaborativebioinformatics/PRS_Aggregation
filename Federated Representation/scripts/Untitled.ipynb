# %%
import pandas as pd
df = pd.read_parquet("data/processed/pgs_variants_master_annotated.parquet")
print(df.columns.tolist())
# Out:
# /Users/shivank/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ['pgs_id', 'pgs_name', 'trait_mapped', 'genome_build', 'weight_type', 'ancestry', 'locus_id', 'coord_source', 'variant_id', 'chr_name', 'chr_position', 'effect_allele', 'other_allele', 'hm_chr', 'hm_pos', 'weight_raw', 'weight_source', 'weight_scaled', 'genes_x', 'gene_region_x', 'consequence', 'mutation_type_x', 'genes_y', 'n_genes', 'most_severe_consequence', 'gene_region_y', 'mutation_type_y', 'status']
